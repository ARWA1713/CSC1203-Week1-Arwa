# %%
# Create empty list
numbers = []

# Ask user to enter 5 numbers
for i in range(5):
    num = float(input(f"Enter number {i+1}: "))
    numbers.append(num)

# Calculations
total = sum(numbers)
average = total / len(numbers)
maximum = max(numbers)
minimum = min(numbers)

# Output
print("Numbers:", numbers)
print("Sum:", total)
print("Average:", average)
print("Maximum:", maximum)
print("Minimum:", minimum)
# Out:
# Enter number 1:  10
# Enter number 2:  20
# Enter number 3:  30
# Enter number 4:  40
# Enter number 5:  50
# Numbers: [10.0, 20.0, 30.0, 40.0, 50.0]
# Sum: 150.0
# Average: 30.0
# Maximum: 50.0
# Minimum: 10.0

# %%
# Create empty list first
words_list = []

# Ask user to enter 5 words
for i in range(5):
    word = input(f"Enter word {i+1}: ")
    words_list.append(word)

# Convert list to tuple
words = tuple(words_list)

# Print first and last word
print("First word:", words[0])
print("Last word:", words[-1])
print("Total number of words:", len(words))

# Check specific word
search_word = input("Enter a word to search: ")

if search_word in words:
    print("The word exists in the tuple.")
else:
    print("The word does not exist in the tuple.")
# Out:
# Enter word 1:  Apple
# Enter word 2:  Banana
# Enter word 3:  Orange
# Enter word 4:  Grape
# Enter word 5:  Mango
# First word: Apple
# Last word: Mango
# Total number of words: 5
# Enter a word to search:  Orange
# The word exists in the tuple.

# %%
# Create empty dictionary
students = {}

# Ask user to enter 3 students
for i in range(3):
    name = input(f"Enter student {i+1} name: ")
    score = float(input(f"Enter {name}'s score: "))
    students[name] = score

# Print all students and scores
print("\nStudents and their scores:")
for name, score in students.items():
    print(name, ":", score)

# Find student with highest score
highest_student = max(students, key=students.get)

print("\nStudent with highest score:", highest_student)
print("Highest score:", students[highest_student])
# Out:
# Enter student 1 name:  Arwa
# Enter Arwa's score:  95
# Enter student 2 name:  Jana
# Enter Jana's score:  90
# Enter student 3 name:  Sara
# Enter Sara's score:  85
# Students and their scores:
# Arwa : 95.0
# Jana : 90.0
# Sara : 85.0
#
# Student with highest score: Arwa
# Highest score: 95.0

# %%
# First list
list1 = input("Enter first list of numbers separated by spaces: ")
list1 = list(map(float, list1.split()))

# Second list
list2 = input("Enter second list of numbers separated by spaces: ")
list2 = list(map(float, list2.split()))

# Convert to sets
set1 = set(list1)
set2 = set(list2)

# Operations
print("Union:", set1.union(set2))
print("Intersection:", set1.intersection(set2))
print("Difference (set1 - set2):", set1.difference(set2))
# Out:
# Enter first list of numbers separated by spaces:  12345
# Enter second list of numbers separated by spaces:  45678
# Union: {12345.0, 45678.0}
# Intersection: set()
# Difference (set1 - set2): {12345.0}

# %%
# Create list
names = []

# Ask user to enter 5 names
for i in range(5):
    name = input(f"Enter name {i+1}: ")
    names.append(name)

# Convert to tuple
names_tuple = tuple(names)
print("Tuple:", names_tuple)

# Create dictionary (name : length)
name_lengths = {}
for name in names:
    name_lengths[name] = len(name)

print("Dictionary (name:length):", name_lengths)

# Create set of unique lengths
unique_lengths = set(name_lengths.values())
print("Unique name lengths:", unique_lengths)
# Out:
# Enter name 1:  Arwa
# Enter name 2:  Jana
# Enter name 3:  lama
# Enter name 4:  Sara
