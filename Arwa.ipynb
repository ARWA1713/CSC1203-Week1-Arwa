# %%
print("Welcome to Python Programming") #welcome message
# Out:
# Welcome to Python Programming

# %%
name="Arwa"

# %%
print(name) #This line prints my name
# Out:
# Arwa

# %%
 cors = "python"

# %%
print(cors)
# Out:
# python

# %%
student_name = "Alice"

# %%
print(student_name, type(student_name))
# Out:
# Alice <class 'str'>

# %%
age=20

# %%
print(age, type(age))
# Out:
# 20 <class 'int'>

# %%
gpa=3.75

# %%
print(gpa, type(gpa))
# Out:
# 3.75 <class 'float'>

# %%
subjects = ["Math", "Python", "Physics"]

# %%
print(subjects, type(subjects))
# Out:
# ['Math', 'Python', 'Physics'] <class 'list'>

# %%
student_info = {"id": 101, "year": 2}

# %%
print(student_info, type(student_info))
# Out:
# {'id': 101, 'year': 2} <class 'dict'>

# %%
skills = {"Python", "SQL"}

# %%
print(skills, type(skills))
# Out:
# {'Python', 'SQL'} <class 'set'>

# %%
is_enrolled = True

# %%
print(is_enrolled, type(is_enrolled))
# Out:
# True <class 'bool'>

# %%
graduation_date = None

# %%
print(graduation_date, type(graduation_date))
# Out:
# None <class 'NoneType'>
